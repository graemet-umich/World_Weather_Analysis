# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.0, 90.0, size=2000)
lngs = np.random.uniform(-180.0, 180.0, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 730

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        # date not required
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | carmen
# Processing Record 2 of Set 1 | rio gallegos
# Processing Record 3 of Set 1 | sergach
# Processing Record 4 of Set 1 | bull savanna
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | fortuna
# Processing Record 7 of Set 1 | ende
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | vao
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | clyde river
# Processing Record 14 of Set 1 | sovetskiy
# Processing Record 15 of Set 1 | barmer
# Processing Record 16 of Set 1 | riosucio
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | iqaluit
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | constitucion
# Processing Record 22 of Set 1 | esperance
# Processing Record 23 of Set 1 | ketchikan
# Processing Record 24 of Set 1 | nelson bay
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | jalu
# Processing Record 27 of Set 1 | port elizabeth
# Processing Record 28 of Set 1 | bure
# Processing Record 29 of Set 1 | mamallapuram
# Processing Record 30 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 1 | okhotsk
# Processing Record 32 of Set 1 | guozhen
# Processing Record 33 of Set 1 | tasiilaq
# Processing Record 34 of Set 1 | geraldton
# Processing Record 35 of Set 1 | taoudenni
# Processing Record 36 of Set 1 | lebu
# Processing Record 37 of Set 1 | kavaratti
# Processing Record 38 of Set 1 | vila franca do campo
# Processing Record 39 of Set 1 | castro
# Processing Record 40 of Set 1 | fairbanks
# Processing Record 41 of Set 1 | sistranda
# Processing Record 42 of Set 1 | rio grande
# Processing Record 43 of Set 1 | mahebourg
# Processing Record 44 of Set 1 | victoria
# Processing Record 45 of Set 1 | baltasi
# Processing Record 46 of Set 1 | portland
# Processing Record 47 of Set 1 | katsuura
# Processing Record 48 of Set 1 | karratha
# Processing Record 49 of Set 1 | xian
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | sabaudia
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | airai
# Processing Record 6 of Set 2 | komsomolskiy
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 2 | saint-esteve
# Processing Record 10 of Set 2 | saskylakh
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | taltal
# Processing Record 13 of Set 2 | sao joao da barra
# Processing Record 14 of Set 2 | provideniya
# Processing Record 15 of Set 2 | talnakh
# Processing Record 16 of Set 2 | usinsk
# Processing Record 17 of Set 2 | richards bay
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | dori
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | chokurdakh
# Processing Record 22 of Set 2 | san quintin
# Processing Record 23 of Set 2 | port alfred
# Processing Record 24 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | saint george
# Processing Record 27 of Set 2 | hobart
# Processing Record 28 of Set 2 | cherskiy
# Processing Record 29 of Set 2 | ust-omchug
# Processing Record 30 of Set 2 | helmsdale
# Processing Record 31 of Set 2 | the pas
# Processing Record 32 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 2 | nome
# Processing Record 34 of Set 2 | saint-philippe
# Processing Record 35 of Set 2 | onega
# Processing Record 36 of Set 2 | moranbah
# Processing Record 37 of Set 2 | pospelikha
# Processing Record 38 of Set 2 | arraial do cabo
# Processing Record 39 of Set 2 | mnogovershinnyy
# Processing Record 40 of Set 2 | cidreira
# Processing Record 41 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 42 of Set 2 | vallenar
# Processing Record 43 of Set 2 | hamilton
# Processing Record 44 of Set 2 | luanda
# Processing Record 45 of Set 2 | ayolas
# Processing Record 46 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 2 | salalah
# Processing Record 48 of Set 2 | puerto escondido
# Processing Record 49 of Set 2 | hambantota
# Processing Record 50 of Set 2 | luwuk
# Processing Record 1 of Set 3 | poselki
# Processing Record 2 of Set 3 | porto santo
# Processing Record 3 of Set 3 | saldanha
# Processing Record 4 of Set 3 | severo-yeniseyskiy
# Processing Record 5 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 7 of Set 3 | ystad
# Processing Record 8 of Set 3 | necochea
# Processing Record 9 of Set 3 | baruun-urt
# Processing Record 10 of Set 3 | westport
# Processing Record 11 of Set 3 | akcakoca
# Processing Record 12 of Set 3 | oeiras do para
# Processing Record 13 of Set 3 | padang
# Processing Record 14 of Set 3 | parry sound
# Processing Record 15 of Set 3 | aklavik
# Processing Record 16 of Set 3 | gizo
# Processing Record 17 of Set 3 | bowen
# Processing Record 18 of Set 3 | acapulco
# Processing Record 19 of Set 3 | faanui
# Processing Record 20 of Set 3 | buala
# Processing Record 21 of Set 3 | maningrida
# Processing Record 22 of Set 3 | glace bay
# Processing Record 23 of Set 3 | lorengau
# Processing Record 24 of Set 3 | ribeira grande
# Processing Record 25 of Set 3 | kloulklubed
# Processing Record 26 of Set 3 | paamiut
# Processing Record 27 of Set 3 | kapaa
# Processing Record 28 of Set 3 | vila velha
# Processing Record 29 of Set 3 | olinda
# Processing Record 30 of Set 3 | caravelas
# Processing Record 31 of Set 3 | shabqadar
# Processing Record 32 of Set 3 | road town
# Processing Record 33 of Set 3 | lompoc
# Processing Record 34 of Set 3 | avarua
# Processing Record 35 of Set 3 | atuona
# Processing Record 36 of Set 3 | san lawrenz
# Processing Record 37 of Set 3 | zinacantan
# Processing Record 38 of Set 3 | waingapu
# Processing Record 39 of Set 3 | pevek
# Processing Record 40 of Set 3 | lubao
# Processing Record 41 of Set 3 | dunedin
# Processing Record 42 of Set 3 | manica
# Processing Record 43 of Set 3 | nanakuli
# Processing Record 44 of Set 3 | pasighat
# Processing Record 45 of Set 3 | sitka
# Processing Record 46 of Set 3 | upernavik
# Processing Record 47 of Set 3 | omsukchan
# Processing Record 48 of Set 3 | torbay
# Processing Record 49 of Set 3 | yellowknife
# Processing Record 50 of Set 3 | port hardy
# Processing Record 1 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 4 | vaini
# Processing Record 3 of Set 4 | isangel
# Processing Record 4 of Set 4 | hami
# Processing Record 5 of Set 4 | nakhon si thammarat
# Processing Record 6 of Set 4 | tuatapere
# Processing Record 7 of Set 4 | kudligi
# Processing Record 8 of Set 4 | tuktoyaktuk
# Processing Record 9 of Set 4 | svetlogorsk
# Processing Record 10 of Set 4 | vestmannaeyjar
# Processing Record 11 of Set 4 | manzanillo
# Processing Record 12 of Set 4 | ancud
# Processing Record 13 of Set 4 | khatanga
# Processing Record 14 of Set 4 | qaanaaq
# Processing Record 15 of Set 4 | saint austell
# Processing Record 16 of Set 4 | tiznit
# Processing Record 17 of Set 4 | verkhoyansk
# Processing Record 18 of Set 4 | san isidro
# Processing Record 19 of Set 4 | lebane
# Processing Record 20 of Set 4 | bathsheba
# Processing Record 21 of Set 4 | kathu
# Processing Record 22 of Set 4 | thompson
# Processing Record 23 of Set 4 | lac du bonnet
# Processing Record 24 of Set 4 | luderitz
# Processing Record 25 of Set 4 | lubango
# Processing Record 26 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 4 | bonavista
# Processing Record 28 of Set 4 | porto novo
# Processing Record 29 of Set 4 | kamina
# Processing Record 30 of Set 4 | mindelo
# Processing Record 31 of Set 4 | lagoa
# Processing Record 32 of Set 4 | pisco
# Processing Record 33 of Set 4 | norman wells
# Processing Record 34 of Set 4 | brunsbuttel
# Processing Record 35 of Set 4 | new norfolk
# Processing Record 36 of Set 4 | valparaiso
# Processing Record 37 of Set 4 | plettenberg bay
# Processing Record 38 of Set 4 | asau
# Processing Record 39 of Set 4 | codrington
# Processing Record 40 of Set 4 | saint-pierre
# Processing Record 41 of Set 4 | namibe
# Processing Record 42 of Set 4 | garissa
# Processing Record 43 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 4 | najran
# Processing Record 45 of Set 4 | hithadhoo
# Processing Record 46 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 4 | kibala
# Processing Record 48 of Set 4 | nikolskoye
# Processing Record 49 of Set 4 | ulladulla
# Processing Record 50 of Set 4 | ola
# Processing Record 1 of Set 5 | puurmani
# Processing Record 2 of Set 5 | coihaique
# Processing Record 3 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 5 | mol
# Processing Record 5 of Set 5 | yola
# Processing Record 6 of Set 5 | beira
# Processing Record 7 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 10 of Set 5 | bethel
# Processing Record 11 of Set 5 | chisec
# Processing Record 12 of Set 5 | praia da vitoria
# Processing Record 13 of Set 5 | celestun
# Processing Record 14 of Set 5 | itoman
# Processing Record 15 of Set 5 | ponta do sol
# Processing Record 16 of Set 5 | kaitangata
# Processing Record 17 of Set 5 | mantua
# Processing Record 18 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 5 | gympie
# Processing Record 20 of Set 5 | jamestown
# Processing Record 21 of Set 5 | timizart
# Processing Record 22 of Set 5 | dmitriyev-lgovskiy
# City not found. Skipping...
# Processing Record 23 of Set 5 | adelaide
# Processing Record 24 of Set 5 | bubaque
# Processing Record 25 of Set 5 | longyearbyen
# Processing Record 26 of Set 5 | naze
# Processing Record 27 of Set 5 | saint-augustin
# Processing Record 28 of Set 5 | cayenne
# Processing Record 29 of Set 5 | carnarvon
# Processing Record 30 of Set 5 | sirmaur
# Processing Record 31 of Set 5 | sal rei
# Processing Record 32 of Set 5 | ratnagiri
# Processing Record 33 of Set 5 | cabo san lucas
# Processing Record 34 of Set 5 | meadow lake
# Processing Record 35 of Set 5 | rumuruti
# Processing Record 36 of Set 5 | emerald
# Processing Record 37 of Set 5 | dingle
# Processing Record 38 of Set 5 | livingstonia
# Processing Record 39 of Set 5 | la ronge
# Processing Record 40 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 5 | yulara
# Processing Record 42 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 44 of Set 5 | katherine
# Processing Record 45 of Set 5 | loknya
# Processing Record 46 of Set 5 | borogontsy
# Processing Record 47 of Set 5 | zunheboto
# Processing Record 48 of Set 5 | xuddur
# Processing Record 49 of Set 5 | ilulissat
# Processing Record 50 of Set 5 | frontera comalapa
# Processing Record 1 of Set 6 | stavtrup
# Processing Record 2 of Set 6 | urengoy
# Processing Record 3 of Set 6 | chhabra
# Processing Record 4 of Set 6 | husavik
# Processing Record 5 of Set 6 | broome
# Processing Record 6 of Set 6 | alyangula
# Processing Record 7 of Set 6 | dondo
# Processing Record 8 of Set 6 | xingyi
# Processing Record 9 of Set 6 | kalmunai
# Processing Record 10 of Set 6 | hasaki
# Processing Record 11 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 12 of Set 6 | zhanaozen
# Processing Record 13 of Set 6 | lavrentiya
# Processing Record 14 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 6 | mackay
# Processing Record 16 of Set 6 | dakar
# Processing Record 17 of Set 6 | kodiak
# Processing Record 18 of Set 6 | balabac
# Processing Record 19 of Set 6 | aswan
# Processing Record 20 of Set 6 | tsienyane
# City not found. Skipping...
# Processing Record 21 of Set 6 | comodoro rivadavia
# Processing Record 22 of Set 6 | kamensk-shakhtinskiy
# Processing Record 23 of Set 6 | karachi
# Processing Record 24 of Set 6 | te anau
# Processing Record 25 of Set 6 | georgetown
# Processing Record 26 of Set 6 | qaqortoq
# Processing Record 27 of Set 6 | aasiaat
# Processing Record 28 of Set 6 | leningradskiy
# Processing Record 29 of Set 6 | anisoc
# Processing Record 30 of Set 6 | sur
# Processing Record 31 of Set 6 | teknaf
# Processing Record 32 of Set 6 | manakara
# Processing Record 33 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 6 | saint-leu
# Processing Record 35 of Set 6 | todos santos
# Processing Record 36 of Set 6 | halifax
# Processing Record 37 of Set 6 | sisimiut
# Processing Record 38 of Set 6 | oksfjord
# Processing Record 39 of Set 6 | mizdah
# Processing Record 40 of Set 6 | jieshi
# Processing Record 41 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 6 | camacha
# Processing Record 43 of Set 6 | vardo
# Processing Record 44 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 6 | quthing
# Processing Record 46 of Set 6 | guerrero negro
# Processing Record 47 of Set 6 | lucapa
# Processing Record 48 of Set 6 | half moon bay
# Processing Record 49 of Set 6 | khasan
# Processing Record 50 of Set 6 | oistins
# Processing Record 1 of Set 7 | mehamn
# Processing Record 2 of Set 7 | dekernes
# Processing Record 3 of Set 7 | vikhorevka
# Processing Record 4 of Set 7 | kaputa
# Processing Record 5 of Set 7 | muli
# Processing Record 6 of Set 7 | bam
# Processing Record 7 of Set 7 | neiafu
# Processing Record 8 of Set 7 | gat
# Processing Record 9 of Set 7 | hualmay
# Processing Record 10 of Set 7 | fort nelson
# Processing Record 11 of Set 7 | malanje
# Processing Record 12 of Set 7 | haysville
# Processing Record 13 of Set 7 | guarapari
# Processing Record 14 of Set 7 | chivacoa
# Processing Record 15 of Set 7 | ubajara
# Processing Record 16 of Set 7 | ostrovnoy
# Processing Record 17 of Set 7 | aykhal
# Processing Record 18 of Set 7 | mecca
# Processing Record 19 of Set 7 | novopavlovka
# Processing Record 20 of Set 7 | east london
# Processing Record 21 of Set 7 | eresos
# Processing Record 22 of Set 7 | smithers
# Processing Record 23 of Set 7 | whitehorse
# Processing Record 24 of Set 7 | pangnirtung
# Processing Record 25 of Set 7 | sidi ali
# Processing Record 26 of Set 7 | araouane
# Processing Record 27 of Set 7 | sosua
# Processing Record 28 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 29 of Set 7 | fukue
# Processing Record 30 of Set 7 | carikar
# City not found. Skipping...
# Processing Record 31 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 7 | boyolangu
# Processing Record 33 of Set 7 | rincon
# Processing Record 34 of Set 7 | farafenni
# Processing Record 35 of Set 7 | buckeye
# Processing Record 36 of Set 7 | bengkulu
# Processing Record 37 of Set 7 | inuvik
# Processing Record 38 of Set 7 | upata
# Processing Record 39 of Set 7 | hovd
# Processing Record 40 of Set 7 | souillac
# Processing Record 41 of Set 7 | lake havasu city
# Processing Record 42 of Set 7 | chateaubelair
# Processing Record 43 of Set 7 | cururupu
# Processing Record 44 of Set 7 | tilichiki
# Processing Record 45 of Set 7 | shebunino
# Processing Record 46 of Set 7 | raudeberg
# Processing Record 47 of Set 7 | alepe
# Processing Record 48 of Set 7 | nouadhibou
# Processing Record 49 of Set 7 | tromso
# Processing Record 50 of Set 7 | ust-kulom
# Processing Record 1 of Set 8 | wukari
# Processing Record 2 of Set 8 | gamba
# Processing Record 3 of Set 8 | cardston
# Processing Record 4 of Set 8 | olafsvik
# Processing Record 5 of Set 8 | balimo
# City not found. Skipping...
# Processing Record 6 of Set 8 | manaure
# Processing Record 7 of Set 8 | marsa matruh
# Processing Record 8 of Set 8 | ruteng
# Processing Record 9 of Set 8 | chuy
# Processing Record 10 of Set 8 | lazaro cardenas
# Processing Record 11 of Set 8 | panama city
# Processing Record 12 of Set 8 | san cristobal
# Processing Record 13 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 14 of Set 8 | angoche
# Processing Record 15 of Set 8 | rawson
# Processing Record 16 of Set 8 | myanaung
# Processing Record 17 of Set 8 | mataram
# Processing Record 18 of Set 8 | harper
# Processing Record 19 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 20 of Set 8 | tari
# Processing Record 21 of Set 8 | nuuk
# Processing Record 22 of Set 8 | bo rai
# Processing Record 23 of Set 8 | bagdarin
# Processing Record 24 of Set 8 | haines junction
# Processing Record 25 of Set 8 | nanortalik
# Processing Record 26 of Set 8 | ahipara
# Processing Record 27 of Set 8 | annau
# Processing Record 28 of Set 8 | kununurra
# Processing Record 29 of Set 8 | maghama
# City not found. Skipping...
# Processing Record 30 of Set 8 | san andres
# Processing Record 31 of Set 8 | shingu
# Processing Record 32 of Set 8 | taybad
# Processing Record 33 of Set 8 | masterton
# Processing Record 34 of Set 8 | muhos
# Processing Record 35 of Set 8 | kutum
# Processing Record 36 of Set 8 | karamken
# City not found. Skipping...
# Processing Record 37 of Set 8 | flin flon
# Processing Record 38 of Set 8 | valdivia
# Processing Record 39 of Set 8 | chernoyerkovskaya
# Processing Record 40 of Set 8 | columbus
# Processing Record 41 of Set 8 | shasta lake
# Processing Record 42 of Set 8 | ankara
# Processing Record 43 of Set 8 | shubarkuduk
# Processing Record 44 of Set 8 | ladario
# Processing Record 45 of Set 8 | chapleau
# Processing Record 46 of Set 8 | dangriga
# Processing Record 47 of Set 8 | harer
# Processing Record 48 of Set 8 | bonthe
# Processing Record 49 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 50 of Set 8 | latung
# Processing Record 1 of Set 9 | san patricio
# Processing Record 2 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 3 of Set 9 | laguna
# Processing Record 4 of Set 9 | acarau
# Processing Record 5 of Set 9 | quatre cocos
# Processing Record 6 of Set 9 | rensvik
# Processing Record 7 of Set 9 | west richland
# Processing Record 8 of Set 9 | barnaul
# Processing Record 9 of Set 9 | meulaboh
# Processing Record 10 of Set 9 | okha
# Processing Record 11 of Set 9 | kuching
# Processing Record 12 of Set 9 | jiangyou
# Processing Record 13 of Set 9 | zlatibor
# Processing Record 14 of Set 9 | shatrovo
# Processing Record 15 of Set 9 | zhitikara
# City not found. Skipping...
# Processing Record 16 of Set 9 | bambous virieux
# Processing Record 17 of Set 9 | odweyne
# Processing Record 18 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 9 | wanaka
# Processing Record 20 of Set 9 | kenai
# Processing Record 21 of Set 9 | port-gentil
# Processing Record 22 of Set 9 | oranjemund
# Processing Record 23 of Set 9 | san javier
# Processing Record 24 of Set 9 | soe
# Processing Record 25 of Set 9 | champerico
# Processing Record 26 of Set 9 | burica
# City not found. Skipping...
# Processing Record 27 of Set 9 | mambajao
# Processing Record 28 of Set 9 | klaksvik
# Processing Record 29 of Set 9 | tahara
# Processing Record 30 of Set 9 | buta
# Processing Record 31 of Set 9 | jvari
# Processing Record 32 of Set 9 | sao filipe
# Processing Record 33 of Set 9 | fort-shevchenko
# Processing Record 34 of Set 9 | bafq
# Processing Record 35 of Set 9 | wangjing
# Processing Record 36 of Set 9 | namatanai
# Processing Record 37 of Set 9 | sainte-marie
# Processing Record 38 of Set 9 | yumen
# Processing Record 39 of Set 9 | arroyo
# Processing Record 40 of Set 9 | ilebo
# Processing Record 41 of Set 9 | benguela
# Processing Record 42 of Set 9 | berbera
# Processing Record 43 of Set 9 | labuhan
# Processing Record 44 of Set 9 | urdoma
# Processing Record 45 of Set 9 | ovsyanka
# Processing Record 46 of Set 9 | san lorenzo
# Processing Record 47 of Set 9 | parana
# Processing Record 48 of Set 9 | martapura
# Processing Record 49 of Set 9 | buraydah
# Processing Record 50 of Set 9 | thinadhoo
# Processing Record 1 of Set 10 | hervey bay
# Processing Record 2 of Set 10 | gornyy
# Processing Record 3 of Set 10 | kamenka
# Processing Record 4 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 5 of Set 10 | severo-kurilsk
# Processing Record 6 of Set 10 | ilmajoki
# Processing Record 7 of Set 10 | machali
# Processing Record 8 of Set 10 | bugiri
# Processing Record 9 of Set 10 | dongsheng
# Processing Record 10 of Set 10 | maciel
# Processing Record 11 of Set 10 | potgietersrus
# City not found. Skipping...
# Processing Record 12 of Set 10 | mount gambier
# Processing Record 13 of Set 10 | lamar
# Processing Record 14 of Set 10 | whitley bay
# Processing Record 15 of Set 10 | llangefni
# Processing Record 16 of Set 10 | hareid
# Processing Record 17 of Set 10 | yatou
# Processing Record 18 of Set 10 | sakaraha
# Processing Record 19 of Set 10 | lumut
# Processing Record 20 of Set 10 | izazi
# Processing Record 21 of Set 10 | sinnamary
# Processing Record 22 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 23 of Set 10 | mayo
# Processing Record 24 of Set 10 | mehkar
# Processing Record 25 of Set 10 | vangaindrano
# Processing Record 26 of Set 10 | fene
# Processing Record 27 of Set 10 | kemi
# Processing Record 28 of Set 10 | kruisfontein
# Processing Record 29 of Set 10 | marfino
# Processing Record 30 of Set 10 | lusambo
# Processing Record 31 of Set 10 | agirish
# Processing Record 32 of Set 10 | mouzakion
# City not found. Skipping...
# Processing Record 33 of Set 10 | lasa
# Processing Record 34 of Set 10 | umri
# Processing Record 35 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 10 | erzin
# Processing Record 37 of Set 10 | kavieng
# Processing Record 38 of Set 10 | othonoi
# City not found. Skipping...
# Processing Record 39 of Set 10 | paramonga
# Processing Record 40 of Set 10 | chumikan
# Processing Record 41 of Set 10 | cahors
# Processing Record 42 of Set 10 | leh
# Processing Record 43 of Set 10 | tiksi
# Processing Record 44 of Set 10 | coahuayana
# Processing Record 45 of Set 10 | tungor
# Processing Record 46 of Set 10 | pandamatenga
# Processing Record 47 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 10 | springfield
# Processing Record 49 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 50 of Set 10 | havelock
# Processing Record 1 of Set 11 | hofn
# Processing Record 2 of Set 11 | babstovo
# Processing Record 3 of Set 11 | sao jose da coroa grande
# Processing Record 4 of Set 11 | coquimbo
# Processing Record 5 of Set 11 | vostok
# Processing Record 6 of Set 11 | athabasca
# Processing Record 7 of Set 11 | ghanzi
# Processing Record 8 of Set 11 | yagodnoye
# Processing Record 9 of Set 11 | puerto del rosario
# Processing Record 10 of Set 11 | beatrice
# Processing Record 11 of Set 11 | sangar
# Processing Record 12 of Set 11 | amahai
# Processing Record 13 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 14 of Set 11 | zlotoryja
# Processing Record 15 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 16 of Set 11 | srednekolymsk
# Processing Record 17 of Set 11 | luau
# Processing Record 18 of Set 11 | price
# Processing Record 19 of Set 11 | esna
# Processing Record 20 of Set 11 | ban phai
# Processing Record 21 of Set 11 | kosh-agach
# Processing Record 22 of Set 11 | belyy
# Processing Record 23 of Set 11 | pacific grove
# Processing Record 24 of Set 11 | college
# Processing Record 25 of Set 11 | kailua
# Processing Record 26 of Set 11 | turayf
# Processing Record 27 of Set 11 | valga
# Processing Record 28 of Set 11 | simbahan
# Processing Record 29 of Set 11 | byron bay
# Processing Record 30 of Set 11 | paciran
# Processing Record 31 of Set 11 | atasu
# Processing Record 32 of Set 11 | palmerston
# Processing Record 33 of Set 11 | aljubarrota
# Processing Record 34 of Set 11 | makushino
# Processing Record 35 of Set 11 | shenkursk
# Processing Record 36 of Set 11 | marawi
# Processing Record 37 of Set 11 | abatskoye
# Processing Record 38 of Set 11 | dukat
# Processing Record 39 of Set 11 | avera
# Processing Record 40 of Set 11 | erenhot
# Processing Record 41 of Set 11 | yenagoa
# Processing Record 42 of Set 11 | santa maria
# Processing Record 43 of Set 11 | sorland
# Processing Record 44 of Set 11 | pocone
# Processing Record 45 of Set 11 | moussoro
# Processing Record 46 of Set 11 | lata
# Processing Record 47 of Set 11 | gorontalo
# Processing Record 48 of Set 11 | alvand
# Processing Record 49 of Set 11 | beringovskiy
# Processing Record 50 of Set 11 | mayor pablo lagerenza
# Processing Record 1 of Set 12 | pathein
# Processing Record 2 of Set 12 | wajid
# Processing Record 3 of Set 12 | jambi
# Processing Record 4 of Set 12 | waitati
# Processing Record 5 of Set 12 | ugoofaaru
# Processing Record 6 of Set 12 | inhambane
# Processing Record 7 of Set 12 | doha
# Processing Record 8 of Set 12 | copiapo
# Processing Record 9 of Set 12 | innisfail
# Processing Record 10 of Set 12 | ko samui
# Processing Record 11 of Set 12 | yazd
# Processing Record 12 of Set 12 | timmins
# Processing Record 13 of Set 12 | teacapan
# Processing Record 14 of Set 12 | erzurum
# Processing Record 15 of Set 12 | aitape
# Processing Record 16 of Set 12 | palmer
# Processing Record 17 of Set 12 | ca mau
# Processing Record 18 of Set 12 | umm lajj
# Processing Record 19 of Set 12 | abu kamal
# Processing Record 20 of Set 12 | alice springs
# Processing Record 21 of Set 12 | kudahuvadhoo
# Processing Record 22 of Set 12 | gari
# Processing Record 23 of Set 12 | dabou
# Processing Record 24 of Set 12 | pangody
# Processing Record 25 of Set 12 | santa rita
# Processing Record 26 of Set 12 | neuquen
# Processing Record 27 of Set 12 | basco
# Processing Record 28 of Set 12 | maposeni
# Processing Record 29 of Set 12 | salitral
# Processing Record 30 of Set 12 | skaudvile
# Processing Record 31 of Set 12 | rostock
# Processing Record 32 of Set 12 | karaton
# Processing Record 33 of Set 12 | pimentel
# Processing Record 34 of Set 12 | tecoanapa
# Processing Record 35 of Set 12 | deer lake
# Processing Record 36 of Set 12 | brae
# Processing Record 37 of Set 12 | saint-joseph
# Processing Record 38 of Set 12 | kieta
# Processing Record 39 of Set 12 | luwingu
# Processing Record 40 of Set 12 | dahuk
# Processing Record 41 of Set 12 | salekhard
# Processing Record 42 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 43 of Set 12 | mogadishu
# Processing Record 44 of Set 12 | faya
# Processing Record 45 of Set 12 | bjornevatn
# Processing Record 46 of Set 12 | isiro
# Processing Record 47 of Set 12 | dzilam gonzalez
# Processing Record 48 of Set 12 | ahvaz
# Processing Record 49 of Set 12 | saint albans
# Processing Record 50 of Set 12 | biak
# Processing Record 1 of Set 13 | dawlatabad
# Processing Record 2 of Set 13 | peniche
# Processing Record 3 of Set 13 | shimoda
# Processing Record 4 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 13 | mana
# Processing Record 6 of Set 13 | narsaq
# Processing Record 7 of Set 13 | chifeng
# Processing Record 8 of Set 13 | grindavik
# Processing Record 9 of Set 13 | ypsonas
# Processing Record 10 of Set 13 | oussouye
# Processing Record 11 of Set 13 | tarija
# Processing Record 12 of Set 13 | owerri
# Processing Record 13 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 14 of Set 13 | nabire
# Processing Record 15 of Set 13 | san juan
# Processing Record 16 of Set 13 | kodinsk
# Processing Record 17 of Set 13 | pitimbu
# Processing Record 18 of Set 13 | adrar
# Processing Record 19 of Set 13 | miramar
# Processing Record 20 of Set 13 | three hills
# Processing Record 21 of Set 13 | iskateley
# Processing Record 22 of Set 13 | bayonet point
# Processing Record 23 of Set 13 | kimbe
# Processing Record 24 of Set 13 | senanga
# Processing Record 25 of Set 13 | port augusta
# Processing Record 26 of Set 13 | nishihara
# Processing Record 27 of Set 13 | barsovo
# Processing Record 28 of Set 13 | vestmanna
# Processing Record 29 of Set 13 | san vicente
# Processing Record 30 of Set 13 | igarka
# Processing Record 31 of Set 13 | krosno odrzanskie
# Processing Record 32 of Set 13 | walvis bay
# Processing Record 33 of Set 13 | bainbridge
# Processing Record 34 of Set 13 | kang
# Processing Record 35 of Set 13 | mahibadhoo
# Processing Record 36 of Set 13 | alofi
# Processing Record 37 of Set 13 | pidhorodna
# Processing Record 38 of Set 13 | hailar
# Processing Record 39 of Set 13 | turukhansk
# Processing Record 40 of Set 13 | napier
# Processing Record 41 of Set 13 | laje
# Processing Record 42 of Set 13 | slave lake
# Processing Record 43 of Set 13 | machico
# Processing Record 44 of Set 13 | arica
# Processing Record 45 of Set 13 | lensk
# Processing Record 46 of Set 13 | anupgarh
# Processing Record 47 of Set 13 | una
# Processing Record 48 of Set 13 | ulkan
# Processing Record 49 of Set 13 | palmares do sul
# Processing Record 50 of Set 13 | natal
# Processing Record 1 of Set 14 | uhlirske janovice
# Processing Record 2 of Set 14 | mokhsogollokh
# Processing Record 3 of Set 14 | sydney
# Processing Record 4 of Set 14 | popondetta
# Processing Record 5 of Set 14 | marquette
# Processing Record 6 of Set 14 | jinchengjiang
# City not found. Skipping...
# Processing Record 7 of Set 14 | arilje
# Processing Record 8 of Set 14 | nueva gerona
# Processing Record 9 of Set 14 | tunkas
# Processing Record 10 of Set 14 | gboko
# Processing Record 11 of Set 14 | rubiataba
# Processing Record 12 of Set 14 | linares
# Processing Record 13 of Set 14 | hope
# Processing Record 14 of Set 14 | kashmor
# Processing Record 15 of Set 14 | chapais
# Processing Record 16 of Set 14 | sakakah
# Processing Record 17 of Set 14 | qui nhon
# Processing Record 18 of Set 14 | garowe
# Processing Record 19 of Set 14 | anloga
# Processing Record 20 of Set 14 | kalabo
# Processing Record 21 of Set 14 | nantucket
# Processing Record 22 of Set 14 | ajdabiya
# Processing Record 23 of Set 14 | samarai
# Processing Record 24 of Set 14 | ordzhonikidze
# Processing Record 25 of Set 14 | tautira
# Processing Record 26 of Set 14 | dekoa
# City not found. Skipping...
# Processing Record 27 of Set 14 | sao felix do xingu
# Processing Record 28 of Set 14 | smidovich
# Processing Record 29 of Set 14 | northam
# Processing Record 30 of Set 14 | pierre
# Processing Record 31 of Set 14 | east wenatchee bench
# Processing Record 32 of Set 14 | soma
# Processing Record 33 of Set 14 | cabedelo
# Processing Record 34 of Set 14 | fougamou
# Processing Record 35 of Set 14 | pemba
# Processing Record 36 of Set 14 | jasper
# Processing Record 37 of Set 14 | maloshuyka
# City not found. Skipping...
# Processing Record 38 of Set 14 | fomboni
# Processing Record 39 of Set 14 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 40 of Set 14 | hirara
# Processing Record 41 of Set 14 | berlevag
# Processing Record 42 of Set 14 | palana
# Processing Record 43 of Set 14 | santa rosa
# Processing Record 44 of Set 14 | payo
# Processing Record 45 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 46 of Set 14 | karasuk
# Processing Record 47 of Set 14 | shaghat
# Processing Record 48 of Set 14 | bani
# Processing Record 49 of Set 14 | conde
# Processing Record 50 of Set 14 | matara
# Processing Record 1 of Set 15 | corinto
# Processing Record 2 of Set 15 | mujiayingzi
# Processing Record 3 of Set 15 | inirida
# Processing Record 4 of Set 15 | snasa
# Processing Record 5 of Set 15 | davila
# Processing Record 6 of Set 15 | bogotol
# Processing Record 7 of Set 15 | peleduy
# Processing Record 8 of Set 15 | honiara
# Processing Record 9 of Set 15 | varca
# Processing Record 10 of Set 15 | astipalaia
# City not found. Skipping...
# Processing Record 11 of Set 15 | waverly
# Processing Record 12 of Set 15 | veraval
# Processing Record 13 of Set 15 | kozhva
# Processing Record 14 of Set 15 | murray bridge
# Processing Record 15 of Set 15 | el badari
# City not found. Skipping...
# Processing Record 16 of Set 15 | sungaipenuh
# Processing Record 17 of Set 15 | margate
# Processing Record 18 of Set 15 | havre-saint-pierre
# Processing Record 19 of Set 15 | tumen
# Processing Record 20 of Set 15 | akersberga
# Processing Record 21 of Set 15 | tessalit
# Processing Record 22 of Set 15 | bambari
# Processing Record 23 of Set 15 | hobyo
# Processing Record 24 of Set 15 | whitianga
# Processing Record 25 of Set 15 | klyuchi
# Processing Record 26 of Set 15 | airdrie
# Processing Record 27 of Set 15 | kautokeino
# Processing Record 28 of Set 15 | addanki
# Processing Record 29 of Set 15 | russell
# Processing Record 30 of Set 15 | fort myers beach
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 668

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
print(city_data_df.shape)
city_data_df.head(10)
# Out:
# (668, 9)
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Carmen  18.6333  -91.8333     84.24        70          20
# 1  Rio Gallegos -51.6226  -69.2181     62.65        34          75
# 2       Sergach  55.5308   45.4661     36.66        87         100
# 3  Bull Savanna  17.8868  -77.5902     80.62        66          31
# 4  Puerto Ayora  -0.7393  -90.3518     75.16        78          69
# 5       Fortuna  40.5982 -124.1573     46.74        96         100
# 6          Ende  -8.8432  121.6623     78.30        88         100
# 7     Busselton -33.6500  115.3333     57.45        84          85
# 8     Cape Town -33.9258   18.4232     64.81        64          75
# 9           Vao -22.6667  167.4833     74.70        85           9
#
#    Wind Speed Country Current Description
# 0        4.61      MX          few clouds
# 1       20.71      AR       broken clouds
# 2       14.50      RU     overcast clouds
# 3        6.89      JM    scattered clouds
# 4        5.99      EC       broken clouds
# 5        5.75      US     overcast clouds
# 6        2.80      ID       moderate rain
# 7        3.60      AU     overcast clouds
# 8       12.66      ZA       broken clouds
# 9       10.09      NC          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Carmen      MX  18.6333  -91.8333     84.24        70          20
# 1  Rio Gallegos      AR -51.6226  -69.2181     62.65        34          75
# 2       Sergach      RU  55.5308   45.4661     36.66        87         100
# 3  Bull Savanna      JM  17.8868  -77.5902     80.62        66          31
# 4  Puerto Ayora      EC  -0.7393  -90.3518     75.16        78          69
# 5       Fortuna      US  40.5982 -124.1573     46.74        96         100
# 6          Ende      ID  -8.8432  121.6623     78.30        88         100
# 7     Busselton      AU -33.6500  115.3333     57.45        84          85
# 8     Cape Town      ZA -33.9258   18.4232     64.81        64          75
# 9           Vao      NC -22.6667  167.4833     74.70        85           9
#
#    Wind Speed Current Description
# 0        4.61          few clouds
# 1       20.71       broken clouds
# 2       14.50     overcast clouds
# 3        6.89    scattered clouds
# 4        5.99       broken clouds
# 5        5.75     overcast clouds
# 6        2.80       moderate rain
# 7        3.60     overcast clouds
# 8       12.66       broken clouds
# 9       10.09          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
